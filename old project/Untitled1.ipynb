# %%
import pandas as pd

# %%
dfs = pd.read_excel('song_data2.xlsx',sheet_name=None)

# %%
artist_tracks = dfs['artist_tracks']
artists = dfs['artists']
tracks=dfs['tracks']

# %%
t = tracks[['name','id']].merge(artist_tracks,left_on='id',right_on='track_id').merge(artists,left_on='artist_id',right_on='id')[['name_x','name_y']]

# %%
t[t['name_y']=='Foster The People']
# Out:
#                                     name_x             name_y
# 226                         Sit Next to Me  Foster The People
# 227                 Pseudologia Fantastica  Foster The People
# 228                                    SHC  Foster The People
# 229                            Pay the Man  Foster The People
# 230                 Doing It for the Money  Foster The People
# 231                                   Ruby  Foster The People
# 232            I Would Do Anything for You  Foster The People
# 233                                Houdini  Foster The People
# 234           Are You What You Want to Be?  Foster The People
# 235                          Coming of Age  Foster The People
# 236                            Helena Beat  Foster The People
# 237                            Best Friend  Foster The People
# 238                        Pumped Up Kicks  Foster The People
# 239                  Call It What You Want  Foster The People
# ...

# %%
tracks[tracks['name']=='Ride or Die (feat. Foster the People)']
# Out:
#                           id                                   name  \
# 1157  3uJsg8xIH7OpWHxuJaMLJX  Ride or Die (feat. Foster the People)
#
#                     album_id  duration  explicit  popularity release_date  \
# 1157  4NSPREWQ2t8VdRGqK45UkD    242034     False          57   2018-03-09
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1157         0.648    0.75    0    -3.248     1       0.0335        0.0609
#
#       instrumentalness  liveness  valence   tempo  time_signature  \
# 1157          0.000004     0.104    0.556  105.03               4
#
#                         artist_list
# 1157  Foster The People, The Knocks

# %%
len(artist_tracks)
# Out:
# 2278
